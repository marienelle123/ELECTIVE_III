# %% [markdown]
# # Activity 1: Data Science with Google Colab
# ### eMathrix Education — Data Science & Data Analytics
#
# **▶ Step 1 (do this first, before any code):** answer the **class intake form** — it collects your identity and a
# quick prior-knowledge check: **https://forms.gle/Z2AJpKTMx5CZcdFq7** (opens in a new tab).
# Pagkatapos ninyong sagutan ang intake form, saka kayo magpatuloy sa Colab sa ibaba.
#
# In this activity you will then connect **your own Google Form survey** to Colab and turn your responses into charts.
#
# **The flow today:**
# 1. **Answer the class intake form** (link above) ← Step 1
# 2. Make a short Google Form of your own (with linked Sheet)
# 3. Get a few responses
# 4. Copy your Sheet ID
# 5. Connect Colab to your Sheet
# 6. Build charts from your own data
#
# Run each cell by clicking it and pressing **Shift + Enter**. Go in order, top to bottom.

# %% [markdown]
# ---
# ## Before you touch any code: make your form
#
# 1. Go to **forms.google.com** and create a new form. Keep it short, 4 to 6 questions, mostly multiple choice.
# 2. In the form, click the **Responses** tab, then the green Sheets icon, then **Create spreadsheet**. This links a Google Sheet that fills automatically.
# 3. **Important:** fill out your own form 5 or 6 times so you have data to chart. No responses means empty charts later. Pwede rin kayong mag-sagutan ng katabi nyo.
# 4. Make sure the Google account you use here in Colab is the **same account that owns the form.** Magkaiba ang account, hindi gagana ang koneksyon.

# %% [markdown]
# ---
# ## Get your Sheet ID
#
# Open your linked Google Sheet. Look at the address bar. The URL looks like this:
#
# `https://docs.google.com/spreadsheets/d/`**`1AbCdEfGhIjKlMnOpQrStUvWxYz1234567890`**`/edit`
#
# The **bold part between `/d/` and `/edit`** is your Sheet ID. Copy it. You'll paste it in Step 4.
#
# > **Important — this is just an example.** The ID above (`1AbCdEfGhIjKlMnOpQrStUvWxYz1234567890`) is a fake placeholder, only to show you what a Sheet ID looks like. It will **not** work. Once you're working on your own, you **must** replace it with the ID from **your own** Google Sheet, signed in with **your own** Google account that owns the form.
# >
# > Halimbawa lang ito. Palitan nyo ng sarili nyong Sheet ID at gamitin ang sarili nyong Google account kapag kayo na ang gagawa.

# %% [markdown]
# ---
# ## Step 1: Install the tools
#
# This installs the libraries that let Colab talk to Google Sheets. Run it once.

# %%
# !pip install gspread google-auth
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.12/dist-packages (6.2.1)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (2.49.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gspread) (1.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth) (49.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth) (4.9.1)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth) (2.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth) (3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2026.6.17)

# %% [markdown]
# ## Step 2: Load the libraries
#
# This brings in pandas (for tables), matplotlib (for charts), and the Google connection tools.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import gspread
from google.auth import default
from google.colab import auth

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## Step 3: Log in to Google
#
# **Heads up before you run this:** a popup will appear asking you to choose your Google account and allow access.
#
# - Pick **your own** Google account — the one that **owns your form**. During class, do **not** use the trainer's example account; sign in as yourself.
# - Click through every **Allow** / **Continue** screen.
# - The popup sometimes hides behind this window or gets blocked. If nothing happens, check for a blocked-popup icon in your address bar, or look behind the browser window.
#
# Tandaan: sariling account nyo ang gamitin, hindi ang account ng trainer.

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

print("Connected to Google!")
print("Ready to open your Google Sheet.")
# Out:
# Connected to Google!
# Ready to open your Google Sheet.

# %% [markdown]
# ## Step 4: Connect to YOUR sheet
#
# Replace the placeholder below with your **own** Sheet ID (the one you copied earlier), then run the cell.
#
# The starting value `PASTE_YOUR_SHEET_ID_HERE` is **just a placeholder** — it will fail on purpose until you swap in your real ID. We set the ID **once here** and reuse it for the rest of the notebook, so you only paste it in one place.

# %%
# ==== PASTE YOUR OWN SHEET ID BETWEEN THE QUOTES ====
SHEET_ID = "1TJgOh7P-rGXdTXEv34ooB3wfU2QY-8M6tjs7ss1FsYY"
# =====================================================

# Connect and pull the data once
try:
    sheet = gc.open_by_key(SHEET_ID).get_worksheet(0)
    data = sheet.get_all_values()

    if len(data) > 1:
        df = pd.DataFrame(data[1:], columns=data[0])
        print(f"SUCCESS! Connected to your survey.")
        print(f"Responses found: {len(df)}")
        print(f"Questions (columns): {len(df.columns)}")
        print("\nYour questions:")
        for i, col in enumerate(df.columns):
            short = col[:60] + "..." if len(col) > 60 else col
            print(f"  Column {i}: {short}")
    else:
        print("Connected, but no responses yet.")
        print("Go fill out your form a few times, then run this cell again.")

except Exception as e:
    print(f"Connection failed: {e}")
    print("\nCheck these:")
    print("1. Is your SHEET_ID pasted correctly (no extra spaces)?")
    print("2. Are you logged in with the account that owns the form?")
    print("3. Did you run Step 3 first?")
# Out:
# SUCCESS! Connected to your survey.
# Responses found: 30
# Questions (columns): 11
#
# Your questions:
#   Column 0: Timestamp
#   Column 1: Do you often experience stress related to your academic resp...
#   Column 2: What is your primary source of stress as a college student? ...
#   Column 3: How do you usually cope with stress? (Checkboxes – choose al...
#   Column 4: Do you think stress affects your academic performance?
#   Column 5: How often do you feel overwhelmed because of school requirem...
#   Column 6:  Have you ever asked for help from your family, friends, tea...
#   Column 7: Which of the following helps you reduce stress the most? (Mu...
#   Column 8:  Do you believe your school provides enough support to help ...
#   Column 9:  In your own words, what usually causes you to feel stressed...
#   Column 10:  What advice or coping strategy would you recommend to other...

# %% [markdown]
# ## Step 5: See your full data table
#
# This shows everything you collected as a clean table. The **Column** numbers shown above are what you'll use to pick which question to chart.

# %%
if len(data) > 1:
    print(f"Rows (responses): {len(df)}")
    print(f"Columns (questions): {len(df.columns)}")
    print("\nYour complete data:")
    from IPython.display import display
    display(df)
else:
    print("No responses yet. Fill out your form first, then re-run Step 4.")
# Out:
# Rows (responses): 30
# Columns (questions): 11
#
# Your complete data:
#              Timestamp  \
# 0   7/13/2026 21:02:17
# 1   7/13/2026 21:05:08
# 2   7/13/2026 21:05:40
# 3   7/13/2026 21:07:25
# 4   7/13/2026 21:07:35
# 5   7/13/2026 21:07:59
# 6   7/13/2026 21:08:08
# 7   7/13/2026 21:21:38
# 8   7/13/2026 21:21:45
#    Which of the following helps you reduce stress the most? (Multiple Choice)  \
# 0   Rest or sleep, Entertainment (music, movies, g...
# 1   Time management, Rest or sleep, Entertainment ...
# 2   Time management, Rest or sleep, Entertainment ...
# 3                                       Rest or sleep
# 4                    Rest or sleep, Physical activity
# 5                Entertainment (music, movies, games)
# 6   Time management, Rest or sleep, Entertainment ...
# 7   Time management, Rest or sleep, Entertainment ...
# 8   Time management, Rest or sleep, Entertainment ...
# 9   Time management, Rest or sleep, Entertainment ...
# 10  Time management, Rest or sleep, Entertainment ...
# 11  Rest or sleep, Entertainment (music, movies, g...
# 12  Rest or sleep, Entertainment (music, movies, g...
# 13                                      Rest or sleep
# 14                                      Rest or sleep
# 15  Entertainment (music, movies, games), Physical...
# 16                     Time management, Rest or sleep
# 17  Rest or sleep, Entertainment (music, movies, g...
# 18  Time management, Rest or sleep, Entertainment ...
# 19  Rest or sleep, Entertainment (music, movies, g...
# 20                   Rest or sleep, Physical activity
# 21                                      Rest or sleep
# 22                                      Rest or sleep
# 23  Rest or sleep, Entertainment (music, movies, g...
# 24                     Time management, Rest or sleep
# 25                                  Physical activity
# 26                                      Rest or sleep
# 27               Entertainment (music, movies, games)
# 28                                  Physical activity
# 29                   Rest or sleep, Physical activity
#
#     Do you believe your school provides enough support to help students manage stress?    \
# 0                                                  No
# 1                                                 Yes
# 2                                                  No
# 3                                            Not Sure
# 4                                            Not Sure
# 5                                            Not Sure
# 6                                            Not Sure
# 7                                            Not Sure
# 8                                                  No
# 9                                                 Yes
# 10                                                 No
# 11                                                 No
# 12                                                 No
# 13                                           Not Sure
# 14                                                 No
# 15                                                 No
# 16                                                Yes
# 17                                           Not Sure
# 18                                                 No
# 19                                                 No
# 20                                                 No
# 21                                                Yes
# 22                                           Not Sure
# 23                                                Yes
# 24                                           Not Sure
# 25                                                Yes
# 26                                           Not Sure
# 27                                                Yes
# 28                                                Yes
# 29                                                 No
#
#     In your own words, what usually causes you to feel stressed as a college student?    \
# 0                          Pressure of being an adult
# 1   There's so much work to do, and the deadline i...
# 2           Too much tasks assigned at the same time.
# 3                           Lots of responsibilities
# 4   What usually causes me the most stress is mana...
# 5                      Overwhelming project deadlines
# 6                          sunod sunod na activities
# 7                        excessive academic workload
# 8              Too much workload with tight deadlines
# 9                                  Too much workloads
# 10                                   family problems
# 11                                  academic pressure
# 12  The cause of stress when someone is thinking t...
# 13                              Overlapping deadlines
# 14  I feel stressed because of a lot of workloads ...
# 15  When a certain professors gives many activitie...
# 16                                                n/a
# 17                                  academic overload
# 18  As a college student, I feel stressed whenever...
# 19                   overloaded acads and family prob
# 20                  pressure from doing school works
# 21                                   financial burden
# 22                                         financial
# 23                       having too much school works
# 24                                      relationship
# 25                      going to school and commuting
# 26                                          financial
# 27                             unstable mental health
# 28                                          fam prob
# 29                              burden of family prob
#
#     What advice or coping strategy would you recommend to other college students who are experiencing stress?
# 0
# 1                                          do it ASAP
# 2   Have better time management and set clear boun...
# 3   You should always calm yourself first and then...
# 4   ​I highly recommend breaking massive projects ...
# 5                                             Survive
# 6
# 7         make sure you manage your time efficiently
# 8   Always prepare yourself, build strong mentalit...
# 9   To manage their time and to take everything sl...
# 10                                             Gumala
# 11                        everything will be worth it
# 12        We need to rest for a bit to ease our minds
# 13                                Take a nap or sleep
# 14  Just manage their time wisely and do their tas...
# 15        try listening to music while walking around
# 16                                                n/a
# 17  take a deep breath, pray, talk to your close f...
# 18  Take one task at a time and manage your time w...
# 19                   listen to music and take a break
# 20                  dont let the stress eat your mind
# 21                        its okay to rest for awhile
# 22                              make time for ur self
# 23                              avoid procrastination
# 24             talk about it kung ano nararamdaman mo
# 25                                           eat more
# 26                               breath in breath out
# 27                                     sleep and rest
# 28                                            gumala
# 29      dont make the other affect your mental health

# %% [markdown]
# ## Step 6: Bar chart of one question
#
# A bar chart counts how many people picked each answer. Change the **`question_column`** number to look at a different question. Look at your column list from Step 4 to pick the number.

# %%
question_column = 2   # change this number to chart a different question

if len(data) > 1 and question_column < len(df.columns):
    question_name = df.columns[question_column]
    answer_counts = df.iloc[:, question_column].value_counts()

    print(f"Bar chart for: {question_name}")

    plt.figure(figsize=(12, 6))
    bars = plt.bar(answer_counts.index.astype(str), answer_counts.values)

    for bar, count in zip(bars, answer_counts.values):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.05,
                 str(count), ha='center', va='bottom', fontweight='bold')

    plt.title(f'{question_name}', fontsize=14, fontweight='bold')
    plt.xlabel('Answers')
    plt.ylabel('Number of people')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()

    print(f"Most popular answer: '{answer_counts.index[0]}' ({answer_counts.iloc[0]} people)")
else:
    print("No data, or that question number does not exist. Check Step 4.")
# Out:
# Bar chart for: What is your primary source of stress as a college student? (Multiple Choice)
# /tmp/ipykernel_2853/2933665215.py:21: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Most popular answer: 'Academic workload, Examinations and quizzes, Time management' (3 people)

# %% [markdown]
# **Notice:** the only thing you changed to chart a different question was the number in `question_column`. That's the whole trick. Try changing it to 2, then re-run this cell.

# %% [markdown]
# ## Step 7: Pie chart of one question
#
# A pie chart shows the same counts as percentages of the whole. Same idea, change `question_column` to pick a question.

# %%
question_column = 5   # change this number to chart a different question

if len(data) > 1 and question_column < len(df.columns):
    question_name = df.columns[question_column]
    answer_counts = df.iloc[:, question_column].value_counts()

    print(f"Pie chart for: {question_name}")

    plt.figure(figsize=(8, 6))
    plt.pie(answer_counts.values,
            labels=answer_counts.index.astype(str),
            autopct=lambda p: f'{p:.0f}%\n({int(round(p*answer_counts.sum()/100))})',
            startangle=90)
    plt.title(f'{question_name}', fontsize=14, fontweight='bold')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

    print(f"Most people answered: '{answer_counts.index[0]}'")
else:
    print("No data, or that question number does not exist. Check Step 4.")
# Out:
# Pie chart for: How often do you feel overwhelmed because of school requirements?
# Most people answered: 'Often'

# %% [markdown]
# ## Step 8: Compare two questions (crosstab)
#
# This is where it gets interesting. A **crosstab** shows how answers to one question relate to answers to another, for example, do people who chose A on question 1 tend to choose X on question 2?
#
# We show it as a grouped bar chart, which is the honest way to compare two categorical questions.

# %%
question_a = 1   # first question
question_b = 2   # second question

if len(data) > 1 and question_a < len(df.columns) and question_b < len(df.columns):
    name_a = df.columns[question_a]
    name_b = df.columns[question_b]

    # Build the crosstab: counts of each combination
    crosstab = pd.crosstab(df.iloc[:, question_a], df.iloc[:, question_b])

    print(f"How '{name_a}' relates to '{name_b}':\n")
    display(crosstab)

    crosstab.plot(kind='bar', figsize=(12, 6))
    plt.title(f'{name_a}  vs  {name_b}', fontsize=13, fontweight='bold')
    plt.xlabel(name_a)
    plt.ylabel('Number of people')
    plt.xticks(rotation=45, ha='right')
    plt.legend(title=name_b, bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()

    print("Each group of bars is one answer to the first question.")
    print("The colors show how those people answered the second question.")
else:
    print("No data, or one of those question numbers does not exist. Check Step 4.")
# Out:
# How 'Do you often experience stress related to your academic responsibilities?  ' relates to 'What is your primary source of stress as a college student? (Multiple Choice)':
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload  \
# Do you often experience stress related to your ...
# Yes                                                                                            2
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes  \
# Do you often experience stress related to your ...
# Yes                                                                                                                      2
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Family responsibilities  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Financial concerns  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Financial concerns, Family responsibilities  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Financial concerns, Family responsibilities, Personal relationships  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Financial concerns, Family responsibilities, Personal relationships, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Financial concerns, Family responsibilities, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Personal relationships, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Examinations and quizzes, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            3
#
# What is your primary source of stress as a college student? (Multiple Choice)  ...  \
# Do you often experience stress related to your ...                             ...
# Yes                                                                            ...
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Financial concerns, Family responsibilities, Personal relationships, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Financial concerns, Family responsibilities, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            2
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Financial concerns, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Academic workload, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                             1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Examinations and quizzes  \
# Do you often experience stress related to your ...
# Yes                                                                                                   1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Examinations and quizzes, Financial concerns, Personal relationships, Time management  \
# Do you often experience stress related to your ...
# Yes                                                                                                                            1
#
# What is your primary source of stress as a college student? (Multiple Choice)  Family responsibilities  \
# Do you often experience stress related to your ...
# Yes                                                                                                  2
#
# What is your primary source of stress as a college student? (Multiple Choice)  Financial concerns, Family responsibilities  \
# Do you often experience stress related to your ...
# Yes                                                                                                                      2
#
# What is your primary source of stress as a college student? (Multiple Choice)  Personal relationships  \
# Do you often experience stress related to your ...
# Yes                                                                                                 2
#
# What is your primary source of stress as a college student? (Multiple Choice)  Personal relationships, Time management
# Do you often experience stress related to your ...
# Yes                                                                                                                  1
#
# [1 rows x 22 columns]
# Each group of bars is one answer to the first question.
# The colors show how those people answered the second question.

# %% [markdown]
# ## Step 9: Full dashboard
#
# This puts a pie chart for each of your questions into one picture, a quick overview of your whole survey.

# %%
if len(data) > 1:
    question_cols = list(range(1, len(df.columns)))  # skip timestamp at column 0
    n = len(question_cols)

    cols = 3
    rows = (n + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 5*rows))
    fig.suptitle('Survey Results Dashboard', fontsize=16, fontweight='bold')

    axes_flat = axes.flatten() if n > 1 else [axes]

    for i, qcol in enumerate(question_cols):
        counts = df.iloc[:, qcol].value_counts()
        axes_flat[i].pie(counts.values,
                         labels=counts.index.astype(str),
                         autopct='%1.0f%%',
                         startangle=90)
        title = df.columns[qcol]
        title = title[:30] + "..." if len(title) > 30 else title
        axes_flat[i].set_title(title, fontsize=10, fontweight='bold')

    # turn off any leftover empty boxes
    for j in range(n, len(axes_flat)):
        axes_flat[j].axis('off')

    plt.tight_layout()
    plt.show()
    print(f"Dashboard created for {n} questions.")
else:
    print("No data to build a dashboard yet. Fill out your form first.")
# Out:
# /tmp/ipykernel_2853/1532176845.py:26: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Dashboard created for 10 questions.

# %% [markdown]
# ---
# ### You did it!
#
# You connected live survey data to code and turned it into charts, the same thing data analysts do every day, just with bigger datasets.
#
# Mahaba pa ang pwedeng gawin dito. Kung gusto nyo ng mas malalim na breakdown, tanong lang.
#
# — eMathrix Education · Data Science & Data Analytics
